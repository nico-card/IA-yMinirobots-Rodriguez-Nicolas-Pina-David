# %% [markdown]
# Nombre: Juan Felipe Fajardo Garzón
#
#
# Diagramas de Voronoi Ciudad Pequeña (Riohacha)

# %% [markdown]
# Para la elaboración del punto se tomó el mapa de Riohacha

# %% [markdown]
# # Centros de Salud

# %% [markdown]
# Inicialmente se resaltaron los centros de salud de Riohacha, teniendo como resultado el siguiente mapa
# ![H_Rioacha_nV.png](data:image/png;base64,...)

# %% [markdown]
# Puesto que todos los centros de salud se encuentran en la zona norte de la ciudad, se tomó una foto con mayor zoom en esta zona en particular, resultando el siguiente diagrama de voronoi
# ![H_Rioacha_V.png](data:image/png;base64,...)

# %% [markdown]
# Se puede observar que a pesar de seleccionar únicamente una zona específica de la ciudad, los centros de salud siguen concentrándose en un espacio en particular, haciendo gran falta uno en la zona inferior izquierda de la imagen

# %% [markdown]
# Por lo tanto después de aplicar un diagrama de voronoi para los centros de salud de la ciudad de Riohacha se puede concluir que estos se encuentran distribuidos de una forma poco uniforme, concentrándose únicamente en la zona "central" y turística de la ciudad, aledaños al malecom; por lo tanto es importante una implementación de más centros de salud en las demás zonas de la ciudad, para facilitar una atención rápida a otros sectores de la ciudad

# %% [markdown]
# # Centros educativos

# %% [markdown]
# Para los centros educativos se tomó el siguiente mapa como punto de partida
#
# ![C_Rioacha_nV.png](data:image/png;base64,...)

# %% [markdown]
# Se observa la misma tendencia que con los centros de salud, la mayoría de centros educativos están ubicados en la zona norte de la ciudad, por lo tanto se va a realizar el mismo proceso, obteniendo el siguiente diagrama de voronoi

# %% [markdown]
# ![C_Rioacha_V.png](data:image/png;base64,...)

# %% [markdown]
# A diferencia de los centros de salud; las instituciones educativas se encuentran distribuidas de una mejor manera por la zona norte de la ciudad, cubriendo la mayor parte de esta. Sin embargo, si lo comparamos con el mapa total de Riohacha, se observa el mismo patrón en el que solo cubren una zona específica de la ciudad, dejando de lado toda la región sur de la ciudad, y por lo tanto, obligando a que los habitantes de esta región se deban desplazar largas distancias para acceder a los servicios
#
# Por ende, es necesario que nuevos centros educativos sean establecidos en la zona sur de la ciudad, evitando asi la marginación de esta región

# %% [markdown]
# # Conclusión

# %% [markdown]
# Ambos diagramas muestran el mismo comportamiento, la zona norte de la ciudad, en especial lo aledaño al malecom (el centro turístico de esta) es la región que posee más servicios como centros de salud o centros educativos; esto puede deberse a que esta fue la primera zona en ser construída de la ciudad, por lo tanto aquí se acumulaban los servicios antes de una gran expansión hacia la zona sur; expansión la cual no se adapto con nuevos centros de servicios para cubrir las necesidades de esta zona de la ciudad, generando la marginación de gran parte de la población de Riohacha
#
# También existe otra teoría y es que posiblemente el mapa no se encuentre actualizado con los centros de salud y educativos de esta zona de la ciudad, o que priorice resultados en la zona central de la misma, lo cual sería una mejor opción debido a que se vería reducida la marginación de gran parte de la población
